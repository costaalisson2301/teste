# %% [markdown]
# <a href="https://colab.research.google.com/github/costaalisson2301/teste/blob/main/atividadepiva1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numero1 = 28
numero2 = 54
print(numero1 *numero2)
# Out:
# 1512

# %%
 numero1 = int(input("Digite um número"))
 numero2 = int(input("Digite outro numero"))
 print(numero1 / numero2)
# Out:
# Digite um número12
# Digite outro numero4
# 3.0

# %%
umero = int(input("Digite um número: "))

if numero < 6:
    print("menor que o necessário")
elif numero > 6:
    print("bom, parabéns")
else:
    print("exatamente 6")

# %%
numero = int(input("Digite um número: "))

if numero < 6:
    print("menor que o necessário")
elif numero > 6:
    print("bom, parabéns")
else:
    print("exatamente 6")

# %%
for i in range(6):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
x = range(15, 30)
x = list(x)

for w in x[3:8]:
    print(w)
# Out:
# 18
# 19
# 20
# 21
# 22

# %%
list [1,2,3]
# Out:
# list[1, 2, 3]

# %%
Idade = int(input("Digite um valor"))
